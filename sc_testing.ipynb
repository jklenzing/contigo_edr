# %% [markdown]
# # Testing Spacecraft and Constellation Class

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
from contigo.spacecraft import Spacecraft

# %%
print(help(Spacecraft))
# Out:
# Help on class Spacecraft in module contigo.spacecraft:
#
# class Spacecraft(builtins.object)
#  |  Spacecraft(state: Union[numpy._typing._array_like._SupportsArray[numpy.dtype[Any]], numpy._typing._nested_sequence._NestedSequence[numpy._typing._array_like._SupportsArray[numpy.dtype[Any]]], bool, int, float, complex, str, bytes, numpy._typing._nested_sequence._NestedSequence[Union[bool, int, float, complex, str, bytes]], NoneType] = None, time: Union[numpy._typing._array_like._SupportsArray[numpy.dtype[Any]], numpy._typing._nested_sequence._NestedSequence[numpy._typing._array_like._SupportsArray[numpy.dtype[Any]]], bool, int, float, complex, str, bytes, numpy._typing._nested_sequence._NestedSequence[Union[bool, int, float, complex, str, bytes]], NoneType] = None, sc_id_input: Union[numpy._typing._array_like._SupportsArray[numpy.dtype[Any]], numpy._typing._nested_sequence._NestedSequence[numpy._typing._array_like._SupportsArray[numpy.dtype[Any]]], bool, int, float, complex, str, bytes, numpy._typing._nested_sequence._NestedSequence[Union[bool, int, float, complex, str, bytes]], NoneType] = None, tscale_input: str | None = None, unit_input: str = 'km', cd: Union[numpy._typing._array_like._SupportsArray[numpy.dtype[Any]], numpy._typing._nested_sequence._NestedSequence[numpy._typing._array_like._SupportsArray[numpy.dtype[Any]]], bool, int, float, complex, str, bytes, numpy._typing._nested_sequence._NestedSequence[Union[bool, int, float, complex, str, bytes]], NoneType] = None, drag_area: Union[numpy._typing._array_like._SupportsArray[numpy.dtype[Any]], numpy._typing._nested_sequence._NestedSequence[numpy._typing._array_like._SupportsArray[numpy.dtype[Any]]], bool, int, float, complex, str, bytes, numpy._typing._nested_sequence._NestedSequence[Union[bool, int, float, complex, str, bytes]], NoneType] = None, sc_mass: Union[numpy._typing._array_like._SupportsArray[numpy.dtype[Any]], numpy._typing._nested_sequence._NestedSequence[numpy._typing._array_like._SupportsArray[numpy.dtype[Any]]], bool, int, float, complex, str, bytes, numpy._typing._nested_sequence._NestedSequence[Union[bool, int, float, complex, str, bytes]], NoneType] = None, cr: Union[numpy._typing._array_like._SupportsArray[numpy.dtype[Any]], numpy._typing._nested_sequence._NestedSequence[numpy._typing._array_like._SupportsArray[numpy.dtype[Any]]], bool, int, float, complex, str, bytes, numpy._typing._nested_sequence._NestedSequence[Union[bool, int, float, complex, str, bytes]], NoneType] = None, srp_area: Union[numpy._typing._array_like._SupportsArray[numpy.dtype[Any]], numpy._typing._nested_sequence._NestedSequence[numpy._typing._array_like._SupportsArray[numpy.dtype[Any]]], bool, int, float, complex, str, bytes, numpy._typing._nested_sequence._NestedSequence[Union[bool, int, float, complex, str, bytes]], NoneType] = None, state_file: Union[str, pathlib.Path, Iterable[str | pathlib.Path], NoneType] = None, time_col: str = 'time', x_col: str = 'x', y_col: str = 'y', z_col: str = 'z', vx_col: str = 'vx', vy_col: str = 'vy', vz_col: str = 'vz', sc_id_col: str | None = None, sc_fn_slc: slice | None = None, cd_col: str | None = None, drag_area_col: str | None = None, sc_mass_col: str | None = None, cr_col: str | None = None, srp_area_col: str | None = None) -> None
#  |
#  |  Spacecraft class for loading and storing spacecraft state info.
#  |
#  |  This is an extended container class for the contigo module
#  |
#  |  Raw inputs may be provided directly (state, time) OR loaded
#  |  from one or more files on disk. Internal state is always strict
#  |  and guaranteed after loading. A simplified container class
#  |  SpacecraftState is used to store the finalized internal state.
#  |
#  |  The state is assumed to be position [x,y,z], velocity [vx,vy,vz] in ECEF
#  |  and spacecraft physical properties and ID.
#  |
#  |  Raises:
#  |      ValueError: _description_
#  |      ValueError: _description_
#  |      ValueError: _description_
#  |      ValueError: _description_
#  |      ValueError: _description_
#  |      ValueError: _description_
#  |      ValueError: _description_
#  |      ValueError: _description_
#  |      ValueError: _description_
#  |      ValueError: _description_
#  |      ValueError: _description_
#  |      FileNotFoundError: _description_
#  |      NotImplementedError: _description_
#  |      ValueError: _description_
#  |
#  |  Returns:
#  |      _type_: _description_
#  |
#  |  Methods defined here:
#  |
#  |  __eq__(self, other)
#  |
#  |  __init__(self, state: Union[numpy._typing._array_like._SupportsArray[numpy.dtype[Any]], numpy._typing._nested_sequence._NestedSequence[numpy._typing._array_like._SupportsArray[numpy.dtype[Any]]], bool, int, float, complex, str, bytes, numpy._typing._nested_sequence._NestedSequence[Union[bool, int, float, complex, str, bytes]], NoneType] = None, time: Union[numpy._typing._array_like._SupportsArray[numpy.dtype[Any]], numpy._typing._nested_sequence._NestedSequence[numpy._typing._array_like._SupportsArray[numpy.dtype[Any]]], bool, int, float, complex, str, bytes, numpy._typing._nested_sequence._NestedSequence[Union[bool, int, float, complex, str, bytes]], NoneType] = None, sc_id_input: Union[numpy._typing._array_like._SupportsArray[numpy.dtype[Any]], numpy._typing._nested_sequence._NestedSequence[numpy._typing._array_like._SupportsArray[numpy.dtype[Any]]], bool, int, float, complex, str, bytes, numpy._typing._nested_sequence._NestedSequence[Union[bool, int, float, complex, str, bytes]], NoneType] = None, tscale_input: str | None = None, unit_input: str = 'km', cd: Union[numpy._typing._array_like._SupportsArray[numpy.dtype[Any]], numpy._typing._nested_sequence._NestedSequence[numpy._typing._array_like._SupportsArray[numpy.dtype[Any]]], bool, int, float, complex, str, bytes, numpy._typing._nested_sequence._NestedSequence[Union[bool, int, float, complex, str, bytes]], NoneType] = None, drag_area: Union[numpy._typing._array_like._SupportsArray[numpy.dtype[Any]], numpy._typing._nested_sequence._NestedSequence[numpy._typing._array_like._SupportsArray[numpy.dtype[Any]]], bool, int, float, complex, str, bytes, numpy._typing._nested_sequence._NestedSequence[Union[bool, int, float, complex, str, bytes]], NoneType] = None, sc_mass: Union[numpy._typing._array_like._SupportsArray[numpy.dtype[Any]], numpy._typing._nested_sequence._NestedSequence[numpy._typing._array_like._SupportsArray[numpy.dtype[Any]]], bool, int, float, complex, str, bytes, numpy._typing._nested_sequence._NestedSequence[Union[bool, int, float, complex, str, bytes]], NoneType] = None, cr: Union[numpy._typing._array_like._SupportsArray[numpy.dtype[Any]], numpy._typing._nested_sequence._NestedSequence[numpy._typing._array_like._SupportsArray[numpy.dtype[Any]]], bool, int, float, complex, str, bytes, numpy._typing._nested_sequence._NestedSequence[Union[bool, int, float, complex, str, bytes]], NoneType] = None, srp_area: Union[numpy._typing._array_like._SupportsArray[numpy.dtype[Any]], numpy._typing._nested_sequence._NestedSequence[numpy._typing._array_like._SupportsArray[numpy.dtype[Any]]], bool, int, float, complex, str, bytes, numpy._typing._nested_sequence._NestedSequence[Union[bool, int, float, complex, str, bytes]], NoneType] = None, state_file: Union[str, pathlib.Path, Iterable[str | pathlib.Path], NoneType] = None, time_col: str = 'time', x_col: str = 'x', y_col: str = 'y', z_col: str = 'z', vx_col: str = 'vx', vy_col: str = 'vy', vz_col: str = 'vz', sc_id_col: str | None = None, sc_fn_slc: slice | None = None, cd_col: str | None = None, drag_area_col: str | None = None, sc_mass_col: str | None = None, cr_col: str | None = None, srp_area_col: str | None = None) -> None
#  |
#  |  __post_init__(self)
#  |      # ------------------------------------------------------------------
#  |      # Construction
#  |      # ------------------------------------------------------------------
#  |
#  |  __repr__(self) -> str
#  |
#  |  load_from_arrays(self, state: Union[numpy._typing._array_like._SupportsArray[numpy.dtype[Any]], numpy._typing._nested_sequence._NestedSequence[numpy._typing._array_like._SupportsArray[numpy.dtype[Any]]], bool, int, float, complex, str, bytes, numpy._typing._nested_sequence._NestedSequence[Union[bool, int, float, complex, str, bytes]]], time: Union[numpy._typing._array_like._SupportsArray[numpy.dtype[Any]], numpy._typing._nested_sequence._NestedSequence[numpy._typing._array_like._SupportsArray[numpy.dtype[Any]]], bool, int, float, complex, str, bytes, numpy._typing._nested_sequence._NestedSequence[Union[bool, int, float, complex, str, bytes]]], sc_id: Union[numpy._typing._array_like._SupportsArray[numpy.dtype[Any]], numpy._typing._nested_sequence._NestedSequence[numpy._typing._array_like._SupportsArray[numpy.dtype[Any]]], bool, int, float, complex, str, bytes, numpy._typing._nested_sequence._NestedSequence[Union[bool, int, float, complex, str, bytes]], NoneType] = None) -> None
#  |      Load spacecraft state from in-memory arrays.
#  |
#  |  load_from_file(self, state_file: Union[str, pathlib.Path, Iterable[str | pathlib.Path]], loader: str | None = None, read_kwargs: dict | None = None) -> None
#  |      Load spacecraft state from one or more files.
#  |
#  |  split_by_id(self) -> dict
#  |      Split a multi-ID Spacecraft container into individual
#  |      Spacecraft objects keyed by spacecraft ID.
#  |
#  |      Returns
#  |      -------
#  |      dict
#  |          {spacecraft_id: Spacecraft}
#  |
#  |  ----------------------------------------------------------------------
#  |  Readonly properties defined here:
#  |
#  |  N
#  |
#  |  n_unique_ids
#  |
#  |  state_data
#  |      Structured grouped view of canonical internal state.
#  |
#  |      Cached after first access.
#  |      Cache automatically invalidated whenever state is reloaded.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  SpacecraftState = <class 'contigo.spacecraft.Spacecraft.SpacecraftStat...
#  |      SpacecraftState(state_ecef: numpy.ndarray[typing.Any, numpy.dtype[numpy.float64]], stime: pandas.core.indexes.datetimes.DatetimeIndex, sc_id: numpy.ndarray[typing.Any, numpy.dtype[+_ScalarType_co]], unique_ids: numpy.ndarray[typing.Any, numpy.dtype[+_ScalarType_co]], cd: numpy.ndarray[typing.Any, numpy.dtype[+_ScalarType_co]], drag_area: numpy.ndarray[typing.Any, numpy.dtype[+_ScalarType_co]], sc_mass: numpy.ndarray[typing.Any, numpy.dtype[+_ScalarType_co]], cr: numpy.ndarray[typing.Any, numpy.dtype[+_ScalarType_co]], srp_area: numpy.ndarray[typing.Any, numpy.dtype[+_ScalarType_co]])
#  |
#  |
#  |  __annotations__ = {'cd': typing.Union[numpy._typing._array_like._Suppo...
#  |
#  |  __dataclass_fields__ = {'cd': Field(name='cd',type=typing.Union[numpy....
#  |
#  |  __dataclass_params__ = _DataclassParams(init=True,repr=True,eq=True,or...
#  |
#  |  __hash__ = None
#  |
#  |  __match_args__ = ('state', 'time', 'sc_id_input', 'tscale_input', 'uni...
#  |
#  |  cd = None
#  |
#  |  cd_col = None
#  |
#  |  cr = None
#  |
#  |  cr_col = None
#  |
#  |  drag_area = None
#  |
#  |  drag_area_col = None
#  |
#  |  sc_fn_slc = None
#  |
#  |  sc_id_col = None
#  |
#  |  sc_id_input = None
#  |
#  |  sc_mass = None
#  |
#  |  sc_mass_col = None
#  |
#  |  srp_area = None
#  |
#  |  srp_area_col = None
#  |
#  |  state = None
#  |
#  |  state_file = None
#  |
#  |  time = None
#  |
#  |  time_col = 'time'
#  |
#  |  tscale_input = None
#  |
#  |  unit_input = 'km'
#  |
#  |  vx_col = 'vx'
#  |
#  |  vy_col = 'vy'
#  |
#  |  vz_col = 'vz'
#  |
#  |  x_col = 'x'
#  |
#  |  y_col = 'y'
#  |
#  |  z_col = 'z'
#
# None

# %% [markdown]
# ### Testing HDF loading

# %%
sw_e = pd.read_hdf("./data/ESA_pod.hdf")
sw_e.columns

# %%
hdf_sc = Spacecraft(state_file=r'D:\GitHub\contigo_edr\data\ESA_pod.hdf', 
                    time_col='DateTime', x_col='x', y_col='y', z_col='z',
                    vx_col='vx', vy_col='vy', vz_col='vz')

# %% [markdown]
# ### Testing Text loading

# %%
# single file loading
csv_sc = Spacecraft(state_file=r'D:\data\SatDensities\Starlink\2025-11-01_STARLINK-11081_catid_60405_trva.csv', 
                    time_col='t_utc', x_col='r_ecef_x', y_col='r_ecef_y', z_col='r_ecef_z',
                    vx_col='v_ecef_x', vy_col='v_ecef_y', vz_col='v_ecef_z')

# %%
# multi file loading
listfiles = [r"D:\data\SatDensities\Starlink\2025-11-01_STARLINK-11082_catid_59711_trva.csv",
r"D:\data\SatDensities\Starlink\2025-11-01_STARLINK-11084_catid_59717_trva.csv",
r"D:\data\SatDensities\Starlink\2025-11-01_STARLINK-11088_catid_59709_trva.csv",
r"D:\data\SatDensities\Starlink\2025-11-01_STARLINK-11081_catid_60405_trva.csv",]

csv_sc = Spacecraft(state_file=listfiles,
                    time_col='t_utc', x_col='r_ecef_x', y_col='r_ecef_y', z_col='r_ecef_z',
                    vx_col='v_ecef_x', vy_col='v_ecef_y', vz_col='v_ecef_z')

# %%
# multi file loading 
# pulling spacecraft IDs from file name
listfiles = [r"D:\data\SatDensities\Starlink\2025-11-01_STARLINK-11082_catid_59711_trva.csv",
r"D:\data\SatDensities\Starlink\2025-11-01_STARLINK-11084_catid_59717_trva.csv",
r"D:\data\SatDensities\Starlink\2025-11-01_STARLINK-11088_catid_59709_trva.csv",
r"D:\data\SatDensities\Starlink\2025-11-01_STARLINK-11081_catid_60405_trva.csv",]

csv_sc = Spacecraft(state_file=listfiles,
                    time_col='t_utc', x_col='r_ecef_x', y_col='r_ecef_y', z_col='r_ecef_z',
                    vx_col='v_ecef_x', vy_col='v_ecef_y', vz_col='v_ecef_z',
                    sc_id_col='filename', sc_fn_slc=slice(-26,-4))

# %%
# compressed files
listfiles = [r"D:\data\SatDensities\Starlink\2025-11-01_STARLINK-11088_catid_59709_trva.csv.zip",
             r"D:\data\SatDensities\Starlink\2025-11-01_STARLINK-11084_catid_59717_trva.csv.zip"]

csv_sc = Spacecraft(state_file=listfiles,
                    time_col='t_utc', x_col='r_ecef_x', y_col='r_ecef_y', z_col='r_ecef_z',
                    vx_col='v_ecef_x', vy_col='v_ecef_y', vz_col='v_ecef_z',
                    sc_id_col='filename', sc_fn_slc=slice(-14,-10))

# %%
# mixed files
listfiles = [r"D:\data\SatDensities\Starlink\2025-11-01_STARLINK-11088_catid_59709_trva.csv.zip",
             r"D:\data\SatDensities\Starlink\2025-11-01_STARLINK-11084_catid_59717_trva.csv.zip",
             r"D:\data\SatDensities\Starlink\2025-11-01_STARLINK-11082_catid_59711_trva.csv",]

csv_sc = Spacecraft(state_file=listfiles,
                    time_col='t_utc', x_col='r_ecef_x', y_col='r_ecef_y', z_col='r_ecef_z',
                    vx_col='v_ecef_x', vy_col='v_ecef_y', vz_col='v_ecef_z',
                    sc_id_col='filename', sc_fn_slc=slice(-14,-10))

# %%
# space craft physical properties
# from columns
listfiles = [r"D:\data\SatDensities\Starlink\2025-11-01_STARLINK-11082_catid_59711_trva.csv"]

csv_sc = Spacecraft(state_file=listfiles,
                    time_col='t_utc', x_col='r_ecef_x', y_col='r_ecef_y', z_col='r_ecef_z',
                    vx_col='v_ecef_x', vy_col='v_ecef_y', vz_col='v_ecef_z',
                    cd_col='drag_coefficient', drag_area_col='drag_area', 
                    srp_area_col='srp_area', sc_mass_col='mass',
                    sc_id_col='filename', sc_fn_slc=slice(-26,-4))

# %%
# Out:
# 1248
