# %% [markdown]
# # Testing Spacecraft and Constellation Class

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
from contigo.spacecraft import Spacecraft
from contigo.constellation import Constellation

# %%
print(help(Spacecraft))
# Out:
# Help on class Spacecraft in module contigo.spacecraft:
#
# class Spacecraft(builtins.object)
#  |  Spacecraft(state: Union[collections.abc.Buffer, numpy._typing._array_like._SupportsArray[numpy.dtype[Any]], numpy._typing._nested_sequence._NestedSequence[numpy._typing._array_like._SupportsArray[numpy.dtype[Any]]], complex, bytes, str, numpy._typing._nested_sequence._NestedSequence[complex | bytes | str], NoneType] = None, time: Union[collections.abc.Buffer, numpy._typing._array_like._SupportsArray[numpy.dtype[Any]], numpy._typing._nested_sequence._NestedSequence[numpy._typing._array_like._SupportsArray[numpy.dtype[Any]]], complex, bytes, str, numpy._typing._nested_sequence._NestedSequence[complex | bytes | str], NoneType] = None, sc_id_input: Union[collections.abc.Buffer, numpy._typing._array_like._SupportsArray[numpy.dtype[Any]], numpy._typing._nested_sequence._NestedSequence[numpy._typing._array_like._SupportsArray[numpy.dtype[Any]]], complex, bytes, str, numpy._typing._nested_sequence._NestedSequence[complex | bytes | str], NoneType] = None, tscale_input: str | None = None, unit_input: str = 'km', cd: Union[float, collections.abc.Buffer, numpy._typing._array_like._SupportsArray[numpy.dtype[Any]], numpy._typing._nested_sequence._NestedSequence[numpy._typing._array_like._SupportsArray[numpy.dtype[Any]]], complex, bytes, str, numpy._typing._nested_sequence._NestedSequence[complex | bytes | str], NoneType] = None, drag_area: Union[float, collections.abc.Buffer, numpy._typing._array_like._SupportsArray[numpy.dtype[Any]], numpy._typing._nested_sequence._NestedSequence[numpy._typing._array_like._SupportsArray[numpy.dtype[Any]]], complex, bytes, str, numpy._typing._nested_sequence._NestedSequence[complex | bytes | str], NoneType] = None, sc_mass: Union[float, collections.abc.Buffer, numpy._typing._array_like._SupportsArray[numpy.dtype[Any]], numpy._typing._nested_sequence._NestedSequence[numpy._typing._array_like._SupportsArray[numpy.dtype[Any]]], complex, bytes, str, numpy._typing._nested_sequence._NestedSequence[complex | bytes | str], NoneType] = None, cr: Union[float, collections.abc.Buffer, numpy._typing._array_like._SupportsArray[numpy.dtype[Any]], numpy._typing._nested_sequence._NestedSequence[numpy._typing._array_like._SupportsArray[numpy.dtype[Any]]], complex, bytes, str, numpy._typing._nested_sequence._NestedSequence[complex | bytes | str], NoneType] = None, srp_area: Union[float, collections.abc.Buffer, numpy._typing._array_like._SupportsArray[numpy.dtype[Any]], numpy._typing._nested_sequence._NestedSequence[numpy._typing._array_like._SupportsArray[numpy.dtype[Any]]], complex, bytes, str, numpy._typing._nested_sequence._NestedSequence[complex | bytes | str], NoneType] = None, state_file: Union[str, pathlib.Path, Iterable[str | pathlib.Path], NoneType] = None, time_col: str = 'time', x_col: str = 'x', y_col: str = 'y', z_col: str = 'z', vx_col: str = 'vx', vy_col: str = 'vy', vz_col: str = 'vz', sc_id_col: str | None = None, sc_fn_slc: slice | None = None, cd_col: str | None = None, drag_area_col: str | None = None, sc_mass_col: str | None = None, cr_col: str | None = None, srp_area_col: str | None = None) -> None
#  |
#  |  Spacecraft class for loading and storing spacecraft state info.
#  |
#  |  This is an extended container class for the contigo module
#  |
#  |  Raw inputs may be provided directly (state, time) OR loaded
#  |  from one or more files on disk. Internal state is always strict
#  |  and guaranteed after loading. A simplified container class
#  |  SpacecraftState is used to store the finalized internal state.
#  |
#  |  The state is assumed to be position [x,y,z], velocity [vx,vy,vz] in ECEF
#  |  and spacecraft physical properties and ID.
#  |
#  |  Raises:
#  |      ValueError: _description_
#  |      ValueError: _description_
#  |      ValueError: _description_
#  |      ValueError: _description_
#  |      ValueError: _description_
#  |      ValueError: _description_
#  |      ValueError: _description_
#  |      ValueError: _description_
#  |      ValueError: _description_
#  |      ValueError: _description_
#  |      ValueError: _description_
#  |      FileNotFoundError: _description_
#  |      NotImplementedError: _description_
#  |      ValueError: _description_
#  |
#  |  Returns:
#  |      _type_: _description_
#  |
#  |  Methods defined here:
#  |
#  |  __eq__(self, other)
#  |      Return self==value.
#  |
#  |  __init__(self, state: Union[collections.abc.Buffer, numpy._typing._array_like._SupportsArray[numpy.dtype[Any]], numpy._typing._nested_sequence._NestedSequence[numpy._typing._array_like._SupportsArray[numpy.dtype[Any]]], complex, bytes, str, numpy._typing._nested_sequence._NestedSequence[complex | bytes | str], NoneType] = None, time: Union[collections.abc.Buffer, numpy._typing._array_like._SupportsArray[numpy.dtype[Any]], numpy._typing._nested_sequence._NestedSequence[numpy._typing._array_like._SupportsArray[numpy.dtype[Any]]], complex, bytes, str, numpy._typing._nested_sequence._NestedSequence[complex | bytes | str], NoneType] = None, sc_id_input: Union[collections.abc.Buffer, numpy._typing._array_like._SupportsArray[numpy.dtype[Any]], numpy._typing._nested_sequence._NestedSequence[numpy._typing._array_like._SupportsArray[numpy.dtype[Any]]], complex, bytes, str, numpy._typing._nested_sequence._NestedSequence[complex | bytes | str], NoneType] = None, tscale_input: str | None = None, unit_input: str = 'km', cd: Union[float, collections.abc.Buffer, numpy._typing._array_like._SupportsArray[numpy.dtype[Any]], numpy._typing._nested_sequence._NestedSequence[numpy._typing._array_like._SupportsArray[numpy.dtype[Any]]], complex, bytes, str, numpy._typing._nested_sequence._NestedSequence[complex | bytes | str], NoneType] = None, drag_area: Union[float, collections.abc.Buffer, numpy._typing._array_like._SupportsArray[numpy.dtype[Any]], numpy._typing._nested_sequence._NestedSequence[numpy._typing._array_like._SupportsArray[numpy.dtype[Any]]], complex, bytes, str, numpy._typing._nested_sequence._NestedSequence[complex | bytes | str], NoneType] = None, sc_mass: Union[float, collections.abc.Buffer, numpy._typing._array_like._SupportsArray[numpy.dtype[Any]], numpy._typing._nested_sequence._NestedSequence[numpy._typing._array_like._SupportsArray[numpy.dtype[Any]]], complex, bytes, str, numpy._typing._nested_sequence._NestedSequence[complex | bytes | str], NoneType] = None, cr: Union[float, collections.abc.Buffer, numpy._typing._array_like._SupportsArray[numpy.dtype[Any]], numpy._typing._nested_sequence._NestedSequence[numpy._typing._array_like._SupportsArray[numpy.dtype[Any]]], complex, bytes, str, numpy._typing._nested_sequence._NestedSequence[complex | bytes | str], NoneType] = None, srp_area: Union[float, collections.abc.Buffer, numpy._typing._array_like._SupportsArray[numpy.dtype[Any]], numpy._typing._nested_sequence._NestedSequence[numpy._typing._array_like._SupportsArray[numpy.dtype[Any]]], complex, bytes, str, numpy._typing._nested_sequence._NestedSequence[complex | bytes | str], NoneType] = None, state_file: Union[str, pathlib.Path, Iterable[str | pathlib.Path], NoneType] = None, time_col: str = 'time', x_col: str = 'x', y_col: str = 'y', z_col: str = 'z', vx_col: str = 'vx', vy_col: str = 'vy', vz_col: str = 'vz', sc_id_col: str | None = None, sc_fn_slc: slice | None = None, cd_col: str | None = None, drag_area_col: str | None = None, sc_mass_col: str | None = None, cr_col: str | None = None, srp_area_col: str | None = None) -> None
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __post_init__(self)
#  |      Post initialization of the Spacecraft class
#  |
#  |      Based on input load data from arrays or files.
#  |
#  |      Raises:
#  |          ValueError: if arrays are provide both a spacecraft state array and
#  |          time array must passed.
#  |          ValueError: either (state, time) arrays must be passed or a container of
#  |          files.
#  |
#  |  __repr__(self) -> str
#  |      Return repr(self).
#  |
#  |  load_from_arrays(self, state: Union[collections.abc.Buffer, numpy._typing._array_like._SupportsArray[numpy.dtype[Any]], numpy._typing._nested_sequence._NestedSequence[numpy._typing._array_like._SupportsArray[numpy.dtype[Any]]], complex, bytes, str, numpy._typing._nested_sequence._NestedSequence[complex | bytes | str]], time: Union[collections.abc.Buffer, numpy._typing._array_like._SupportsArray[numpy.dtype[Any]], numpy._typing._nested_sequence._NestedSequence[numpy._typing._array_like._SupportsArray[numpy.dtype[Any]]], complex, bytes, str, numpy._typing._nested_sequence._NestedSequence[complex | bytes | str]], sc_id: Union[collections.abc.Buffer, numpy._typing._array_like._SupportsArray[numpy.dtype[Any]], numpy._typing._nested_sequence._NestedSequence[numpy._typing._array_like._SupportsArray[numpy.dtype[Any]]], complex, bytes, str, numpy._typing._nested_sequence._NestedSequence[complex | bytes | str], NoneType] = None) -> None
#  |      Load spacecraft state from arrays passed in creation.
#  |
#  |      Args:
#  |          state (npt.ArrayLike): (N,6) spacecraft state [x,y,z,vx,vy,vz]
#  |
#  |          time (npt.ArrayLike): (N,) time associated with spacecraft state
#  |
#  |          sc_id (npt.ArrayLike | None, optional): spacecraft IDs to parse. Defaults to None.
#  |
#  |      Raises:
#  |          ValueError: make sure spacecraft state is (N,6) containing position [x,y,z] and
#  |          velocity [vx,vy,vz].
#  |
#  |          ValueError: spacecraft state and time must have the same number of elements in
#  |          the dimensions.
#  |
#  |          ValueError: if passed spacecraft IDs must (N,)
#  |
#  |  load_from_file(self, state_file: Union[str, pathlib.Path, Iterable[str | pathlib.Path]], loader: str | None = None, read_kwargs: dict | None = None) -> None
#  |      Load spacecraft state from one or more files.
#  |
#  |      Args:
#  |          state_file (str | Path | Iterable[str  |  Path]): Files to load into spacecraft
#  |          state. Specific columns are required to be loaded (time, x, y, z, vx, vy, vs).
#  |          optional columns are (spacecraft id, coeffecient of drag, drag area, spacecraft
#  |          mass, coeffecient of reflection, SRP area).
#  |
#  |          loader (str | None, optional): Specify the loader to use to when parseing the
#  |          state files (state_file). If it is None then the loader is inferred from the
#  |          file extension. The loaders which can be used are pandas.read_csv(),
#  |          pandas.read_hdf(), or contigo.utils.df_sp3() Defaults to None.
#  |
#  |          read_kwargs (dict | None, optional): Keyword arguments to pass to the loaders.
#  |          Defaults to None.
#  |
#  |      Raises:
#  |          ValueError: Specific columns must be defined when reading data.
#  |          (t, x, y, z, vx, vy, vz).
#  |
#  |          ValueError: Spacecraft state must be (N,6).
#  |
#  |          ValueError: First dimension of Spacecraft state and time must be N.
#  |
#  |  split_by_id(self) -> dict
#  |      Split a multi-ID Spacecraft container into individual
#  |      Spacecraft objects keyed by spacecraft ID.
#  |
#  |      Returns
#  |      -------
#  |      dict
#  |          {spacecraft_id: Spacecraft}
#  |
#  |  ----------------------------------------------------------------------
#  |  Readonly properties defined here:
#  |
#  |  N
#  |      Number of elements in Spacecraft state/time
#  |
#  |      Returns:
#  |          int: Number of elements in Spacecraft state/time
#  |
#  |  n_unique_ids
#  |      Number of unique Spacecraft loaded
#  |
#  |      Returns:
#  |          int: Number of unique Spacecraft loaded
#  |
#  |  state_data
#  |      Structured grouped view of canonical internal state.
#  |
#  |      Cached after first access.
#  |      Cache automatically invalidated whenever state is reloaded.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  SpacecraftState = <class 'contigo.spacecraft.Spacecraft.SpacecraftStat...
#  |      SpacecraftState(state_ecef: numpy.ndarray[tuple[typing.Any, ...], numpy.dtype[numpy.float64]], stime: pandas.DatetimeIndex, sc_id: numpy.ndarray[tuple[typing.Any, ...], numpy.dtype[~_ScalarT]], unique_ids: numpy.ndarray[tuple[typing.Any, ...], numpy.dtype[~_ScalarT]], cd: numpy.ndarray[tuple[typing.Any, ...], numpy.dtype[~_ScalarT]], drag_area: numpy.ndarray[tuple[typing.Any, ...], numpy.dtype[~_ScalarT]], sc_mass: numpy.ndarray[tuple[typing.Any, ...], numpy.dtype[~_ScalarT]], cr: numpy.ndarray[tuple[typing.Any, ...], numpy.dtype[~_ScalarT]], srp_area: numpy.ndarray[tuple[typing.Any, ...], numpy.dtype[~_ScalarT]])
#  |
#  |
#  |  __annotations__ = {'cd': typing.Union[float, collections.abc.Buffer, n...
#  |
#  |  __dataclass_fields__ = {'cd': Field(name='cd',type=typing.Union[float,...
#  |
#  |  __dataclass_params__ = _DataclassParams(init=True,repr=True,eq=True,or...
#  |
#  |  __hash__ = None
#  |
#  |  __match_args__ = ('state', 'time', 'sc_id_input', 'tscale_input', 'uni...
#  |
#  |  cd = None
#  |
#  |  cd_col = None
#  |
#  |  cr = None
#  |
#  |  cr_col = None
#  |
#  |  drag_area = None
#  |
#  |  drag_area_col = None
#  |
#  |  sc_fn_slc = None
#  |
#  |  sc_id_col = None
#  |
#  |  sc_id_input = None
#  |
#  |  sc_mass = None
#  |
#  |  sc_mass_col = None
#  |
#  |  srp_area = None
#  |
#  |  srp_area_col = None
#  |
#  |  state = None
#  |
#  |  state_file = None
#  |
#  |  time = None
#  |
#  |  time_col = 'time'
#  |
#  |  tscale_input = None
#  |
#  |  unit_input = 'km'
#  |
#  |  vx_col = 'vx'
#  |
#  |  vy_col = 'vy'
#  |
#  |  vz_col = 'vz'
#  |
#  |  x_col = 'x'
#  |
#  |  y_col = 'y'
#  |
#  |  z_col = 'z'
#
# None

# %% [markdown]
# ### Testing HDF loading

# %%
sw_e = pd.read_hdf("./data/ESA_pod.hdf")
sw_e.columns

# %%
hdf_sc = Spacecraft(state_file=r'D:\GitHub\contigo_edr\data\ESA_pod.hdf', 
                    time_col='DateTime', x_col='x', y_col='y', z_col='z',
                    vx_col='vx', vy_col='vy', vz_col='vz')

# %% [markdown]
# ### Testing Text loading

# %%
# single file loading
csv_sc = Spacecraft(state_file=r'D:\data\SatDensities\Starlink\2025-11-01_STARLINK-11081_catid_60405_trva.csv', 
                    time_col='t_utc', x_col='r_ecef_x', y_col='r_ecef_y', z_col='r_ecef_z',
                    vx_col='v_ecef_x', vy_col='v_ecef_y', vz_col='v_ecef_z')

# %%
# multi file loading
listfiles = [r"D:\data\SatDensities\Starlink\2025-11-01_STARLINK-11082_catid_59711_trva.csv",
r"D:\data\SatDensities\Starlink\2025-11-01_STARLINK-11084_catid_59717_trva.csv",
r"D:\data\SatDensities\Starlink\2025-11-01_STARLINK-11088_catid_59709_trva.csv",
r"D:\data\SatDensities\Starlink\2025-11-01_STARLINK-11081_catid_60405_trva.csv",]

csv_sc = Spacecraft(state_file=listfiles,
                    time_col='t_utc', x_col='r_ecef_x', y_col='r_ecef_y', z_col='r_ecef_z',
                    vx_col='v_ecef_x', vy_col='v_ecef_y', vz_col='v_ecef_z')

# %%
# multi file loading 
# pulling spacecraft IDs from file name
listfiles = [r"D:\data\SatDensities\Starlink\2025-11-01_STARLINK-11082_catid_59711_trva.csv",
r"D:\data\SatDensities\Starlink\2025-11-01_STARLINK-11084_catid_59717_trva.csv",
r"D:\data\SatDensities\Starlink\2025-11-01_STARLINK-11088_catid_59709_trva.csv",
r"D:\data\SatDensities\Starlink\2025-11-01_STARLINK-11081_catid_60405_trva.csv",]

csv_sc = Spacecraft(state_file=listfiles,
                    time_col='t_utc', x_col='r_ecef_x', y_col='r_ecef_y', z_col='r_ecef_z',
                    vx_col='v_ecef_x', vy_col='v_ecef_y', vz_col='v_ecef_z',
                    sc_id_col='filename', sc_fn_slc=slice(-26,-4))

# %%
# compressed files
listfiles = [r"D:\data\SatDensities\Starlink\2025-11-01_STARLINK-11088_catid_59709_trva.csv.zip",
             r"D:\data\SatDensities\Starlink\2025-11-01_STARLINK-11084_catid_59717_trva.csv.zip"]

csv_sc = Spacecraft(state_file=listfiles,
                    time_col='t_utc', x_col='r_ecef_x', y_col='r_ecef_y', z_col='r_ecef_z',
                    vx_col='v_ecef_x', vy_col='v_ecef_y', vz_col='v_ecef_z',
                    sc_id_col='filename', sc_fn_slc=slice(-14,-10))

# %%
# mixed files
listfiles = [r"D:\data\SatDensities\Starlink\2025-11-01_STARLINK-11088_catid_59709_trva.csv.zip",
             r"D:\data\SatDensities\Starlink\2025-11-01_STARLINK-11084_catid_59717_trva.csv.zip",
             r"D:\data\SatDensities\Starlink\2025-11-01_STARLINK-11082_catid_59711_trva.csv",]

csv_sc = Spacecraft(state_file=listfiles,
                    time_col='t_utc', x_col='r_ecef_x', y_col='r_ecef_y', z_col='r_ecef_z',
                    vx_col='v_ecef_x', vy_col='v_ecef_y', vz_col='v_ecef_z',
                    sc_id_col='filename', sc_fn_slc=slice(-14,-10))

# %%
# space craft physical properties
# from columns
listfiles = [r"D:\data\SatDensities\Starlink\2025-11-01_STARLINK-11082_catid_59711_trva.csv"]

csv_sc = Spacecraft(state_file=listfiles,
                    time_col='t_utc', x_col='r_ecef_x', y_col='r_ecef_y', z_col='r_ecef_z',
                    vx_col='v_ecef_x', vy_col='v_ecef_y', vz_col='v_ecef_z',
                    cd_col='drag_coefficient', drag_area_col='drag_area', 
                    srp_area_col='srp_area', sc_mass_col='mass',
                    sc_id_col='filename', sc_fn_slc=slice(-26,-4))

# %% [markdown]
# ### SP3 Files

# %%
listfiles = [r"D:\data\SatDensities\SWARM\SWB\SP3xCOM\SW_OPER_SP3BCOM_2__20180104T235942_20180105T235942_0201.sp3"]

csv_sc = Spacecraft(state_file=listfiles, sc_id_col='sat')

# %% [markdown]
# ### Mixed Files
#
# This might be possible with kwargs and renamin columns. Will have to look into this more.

# %% [markdown]
# ### Constellation

# %%
listfiles = [r"D:\data\SatDensities\Starlink\2025-11-01_STARLINK-11082_catid_59711_trva.csv",
r"D:\data\SatDensities\Starlink\2025-11-01_STARLINK-11084_catid_59717_trva.csv",
r"D:\data\SatDensities\Starlink\2025-11-01_STARLINK-11088_catid_59709_trva.csv",
r"D:\data\SatDensities\Starlink\2025-11-01_STARLINK-11081_catid_60405_trva.csv",]

sc_constellation = Constellation(state_file=listfiles,
                    time_col='t_utc', x_col='r_ecef_x', y_col='r_ecef_y', z_col='r_ecef_z',
                    vx_col='v_ecef_x', vy_col='v_ecef_y', vz_col='v_ecef_z',
                    sc_id_col='filename', sc_fn_slc=slice(-26,-4))

# %%
sc_constellation.spacecraft
# Out:
# {'11081_catid_60405_trva': Spacecraft(N=1226), n_unique_ids=1, ,
#  '11082_catid_59711_trva': Spacecraft(N=1248), n_unique_ids=1, ,
#  '11084_catid_59717_trva': Spacecraft(N=1256), n_unique_ids=1, ,
#  '11088_catid_59709_trva': Spacecraft(N=1246), n_unique_ids=1, }
