# %% [markdown]
# # Testing Spacecraft and Constellation Class

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
from contigo.spacecraft import Spacecraft

# %% [markdown]
# ### Testing HDF loading

# %%
sw_e = pd.read_hdf("./data/ESA_pod.hdf")
sw_e.columns
# Out:
# Index(['index', 'sat', 'x', 'y', 'z', 'DateTime', 'vx', 'vy', 'vz',
#        'EstSat.EarthFixed.X', 'EstSat.EarthFixed.Y', 'EstSat.EarthFixed.Z',
#        'EstSat.EarthFixed.VX', 'EstSat.EarthFixed.VY', 'EstSat.EarthFixed.VZ',
#        'EstSat.TAIGregorian', 'eci_x', 'eci_y', 'eci_z', 'eci_vx', 'eci_vy',
#        'eci_vz', 'eg_x', 'eg_y', 'eg_z', 'sg_x', 'sg_y', 'sg_z', 'mg_x',
#        'mg_y', 'mg_z', 'srp_x', 'srp_y', 'srp_z'],
#       dtype='str')

# %%
hdf_sc = Spacecraft(state_file=r'D:\GitHub\contigo_edr\data\ESA_pod.hdf', 
                    time_col='DateTime', x_col='x', y_col='y', z_col='z',
                    vx_col='vx', vy_col='vy', vz_col='vz')
# Out:
# {'y', 'vz', 'vy', 'DateTime', 'vx', 'x', 'z'}
# {'y', 'vz', 'sg_x', 'srp_x', 'srp_z', 'eci_x', 'eci_y', 'eci_z', 'vx', 'eci_vz', 'eg_x', 'vy', 'EstSat.EarthFixed.Y', 'sg_z', 'sg_y', 'EstSat.EarthFixed.X', 'x', 'eg_z', 'mg_z', 'sat', 'srp_y', 'index', 'eci_vy', 'z', 'EstSat.EarthFixed.VY', 'EstSat.TAIGregorian', 'eg_y', 'eci_vx', 'mg_x', 'EstSat.EarthFixed.VX', 'mg_y', 'EstSat.EarthFixed.VZ', 'DateTime', 'EstSat.EarthFixed.Z'}

# %% [markdown]
# ### Testing Text loading

# %%
# single file loading
csv_sc = Spacecraft(state_file=r'D:\data\SatDensities\Starlink\2025-11-01_STARLINK-11081_catid_60405_trva.csv', 
                    time_col='t_utc', x_col='r_ecef_x', y_col='r_ecef_y', z_col='r_ecef_z',
                    vx_col='v_ecef_x', vy_col='v_ecef_y', vz_col='v_ecef_z')

# %%
# multi file loading
listfiles = [r"D:\data\SatDensities\Starlink\2025-11-01_STARLINK-11082_catid_59711_trva.csv",
r"D:\data\SatDensities\Starlink\2025-11-01_STARLINK-11084_catid_59717_trva.csv",
r"D:\data\SatDensities\Starlink\2025-11-01_STARLINK-11088_catid_59709_trva.csv",
r"D:\data\SatDensities\Starlink\2025-11-01_STARLINK-11081_catid_60405_trva.csv",]

csv_sc = Spacecraft(state_file=listfiles,
                    time_col='t_utc', x_col='r_ecef_x', y_col='r_ecef_y', z_col='r_ecef_z',
                    vx_col='v_ecef_x', vy_col='v_ecef_y', vz_col='v_ecef_z')

# %%
# multi file loading 
# pulling spacecraft IDs from file name
listfiles = [r"D:\data\SatDensities\Starlink\2025-11-01_STARLINK-11082_catid_59711_trva.csv",
r"D:\data\SatDensities\Starlink\2025-11-01_STARLINK-11084_catid_59717_trva.csv",
r"D:\data\SatDensities\Starlink\2025-11-01_STARLINK-11088_catid_59709_trva.csv",
r"D:\data\SatDensities\Starlink\2025-11-01_STARLINK-11081_catid_60405_trva.csv",]

csv_sc = Spacecraft(state_file=listfiles,
                    time_col='t_utc', x_col='r_ecef_x', y_col='r_ecef_y', z_col='r_ecef_z',
                    vx_col='v_ecef_x', vy_col='v_ecef_y', vz_col='v_ecef_z',
                    sc_id_col='filename', sc_fn_slc=slice(-26,-4))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 8
#       1 # multi file loading
#       2 # pulling spacecraft IDs from file name
#       3 listfiles = [r"D:\data\SatDensities\Starlink\2025-11-01_STARLINK-11082_catid_59711_trva.csv",
#       4 r"D:\data\SatDensities\Starlink\2025-11-01_STARLINK-11084_catid_59717_trva.csv",
#       5 r"D:\data\SatDensities\Starlink\2025-11-01_STARLINK-11088_catid_59709_trva.csv",
#       6 r"D:\data\SatDensities\Starlink\2025-11-01_STARLINK-11081_catid_60405_trva.csv",]
# ----> 8 csv_sc = Spacecraft(state_file=listfiles,
#       9                     time_col='t_utc', x_col='r_ecef_x', y_col='r_ecef_y', z_col='r_ecef_z',
#      10                     vx_col='v_ecef_x', vy_col='v_ecef_y', vz_col='v_ecef_z',
#      11                     sc_id_col='filename', sc_fn_slc=slice(-26,-4))
#
# TypeError: Spacecraft.__init__() got an unexpected keyword argument 'sc_fn_slc'

# %%
listfiles[0][-26:-4]
# Out:
# '11082_catid_59711_trva'
